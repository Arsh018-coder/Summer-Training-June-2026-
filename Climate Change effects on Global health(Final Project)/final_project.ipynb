# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
global_df = pd.read_csv('/content/global_climate_health_impact_tracker_2015_2025..csv')

# %%
global_df
# Out:
#        record_id country_code   country_name         region  income_level  \
# 0              1          USA  United States  North America          High
# 1              2          USA  United States  North America          High
# 2              3          USA  United States  North America          High
# 3              4          USA  United States  North America          High
# 4              5          USA  United States  North America          High
# ...          ...          ...            ...            ...           ...
# 14095      14096          COL       Colombia  South America  Upper-Middle
# 14096      14097          COL       Colombia  South America  Upper-Middle
# 14097      14098          COL       Colombia  South America  Upper-Middle
# 14098      14099          COL       Colombia  South America  Upper-Middle
# 14099      14100          COL       Colombia  South America  Upper-Middle
#
#              date  year  month  week  latitude  ...  air_quality_index  \
# ...

# %%
global_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14100 entries, 0 to 14099
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     14100 non-null  int64
#  1   country_code                  14100 non-null  object
#  2   country_name                  14100 non-null  object
#  3   region                        14100 non-null  object
#  4   income_level                  14100 non-null  object
#  5   date                          14100 non-null  object
#  6   year                          14100 non-null  int64
#  7   month                         14100 non-null  int64
#  8   week                          14100 non-null  int64
#  9   latitude                      14100 non-null  float64
#  10  longitude                     14100 non-null  float64
#  11  population_millions           14100 non-null  int64
# ...

# %%
global_df.describe()
# Out:
#           record_id          year         month          week      latitude  \
# count  14100.000000  14100.000000  14100.000000  14100.000000  14100.000000
# mean    7050.500000   2019.911348      6.437943     26.221631     18.905200
# std     4070.463733      3.118225      3.421173     14.930110     25.730498
# min        1.000000   2015.000000      1.000000      1.000000    -38.410000
# 25%     3525.750000   2017.000000      3.000000     13.000000      4.570000
# 50%     7050.500000   2020.000000      6.000000     26.000000     23.630000
# 75%    10575.250000   2023.000000      9.000000     39.000000     37.090000
# max    14100.000000   2025.000000     12.000000     53.000000     56.130000
#
#           longitude  population_millions  temperature_celsius  \
# count  14100.000000         14100.000000         14100.000000
# mean      27.349600           217.440000             8.607113
# std       76.062029           355.979373            11.289938
# ...
